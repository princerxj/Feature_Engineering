# %% [markdown]
# ### 5 Number Summary and Box Plot

# %%
## Minimum , Maximum, Median, Q1, Q3, IQR

# %%
import numpy as np

# %%
lst_marks = [45,32,56,75,89,54,32,89,90,87,98,99,67,45,74]
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum
# Out:
# np.float64(32.0)

# %%
Q1
# Out:
# np.float64(49.5)

# %%
median
# Out:
# np.float64(74.0)

# %%
Q3
# Out:
# np.float64(89.0)

# %%
maximum
# Out:
# np.float64(99.0)

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 39.5

# %%
lower_fence = Q1 - 1.5 * IQR
higher_fence = Q3 + 1.5 * IQR
print(lower_fence, higher_fence)
# Out:
# -9.75 148.25

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-100,-121,45,32,56,75,89,54,32,89,90,87,98,99,67,45,74, 150, 170]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
